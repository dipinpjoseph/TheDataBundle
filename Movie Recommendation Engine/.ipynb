# %%
import numpy as np
import pandas as pd
import re

# %%
movie_link_mapper = pd.read_csv('Data Sets/ml-20m/links.csv')

# %%
movie_link_mapper.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
movie_details = pd.read_csv('Data Sets/ml-20m/movies.csv')

# %%
movie_details.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movie_details['title'].head()
# Out:
# 0                      Toy Story (1995)
# 1                        Jumanji (1995)
# 2               Grumpier Old Men (1995)
# 3              Waiting to Exhale (1995)
# 4    Father of the Bride Part II (1995)
# Name: title, dtype: object

# %%
def year_extractor(title):
    try:
        year = int(title[-5:-1])
        return (year)
    except:
        return (0)

# %%
movie_details['year'] = movie_details['title'].apply(year_extractor)

# %%
movie_details[if movie_details['year'] == 0]
# Out:
#   File "<ipython-input-111-092166b0a6a2>", line 1
#     movie_details[if movie_details['year'] == 0]
#                    ^
# SyntaxError: invalid syntax
